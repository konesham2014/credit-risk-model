# %%
import sys

sys.path.append("..")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from src.data_processing import *

df = load_data("../data/raw/data.csv")

df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
summarize(df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  str
#  1   BatchId               95662 non-null  str
#  2   AccountId             95662 non-null  str
#  3   SubscriptionId        95662 non-null  str
#  4   CustomerId            95662 non-null  str
#  5   CurrencyCode          95662 non-null  str
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  str
#  8   ProductId             95662 non-null  str
#  9   ProductCategory       95662 non-null  str
#  10  ChannelId             95662 non-null  str
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  str
#  14  PricingStrategy       95662 non-null  int64
# ...

# %%
missing_values(df)
# Out:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
msno.matrix(df)
plt.show()

# %%
numeric = ["Amount","Value"]

for col in numeric:

    plt.figure(figsize=(8,5))

    sns.histplot(df[col])

    plt.title(col)

    plt.show()

# %%
plt.figure(figsize=(10,5))

df["ChannelId"].value_counts().plot(
    kind="bar"
)

plt.title("Channel Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.heatmap(

df[["Amount","Value"]].corr(),

annot=True

)

plt.show()

# %%
sns.boxplot(

x=df["Amount"]

)

plt.show()

# %% [markdown]
# # Key Insights
#
# 1. Transaction amounts exhibit significant skewness and outliers.
#
# 2. Missing values are limited and manageable through preprocessing.
#
# 3. Customer transactions are concentrated around specific channels.
#
# 4. Transaction value strongly correlates with transaction amount.
#
# 5. Outliers suggest that robust scaling methods may improve model performance.
